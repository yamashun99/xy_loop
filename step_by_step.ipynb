# %%
import random
import conf
import importlib
import numpy as np
import mpl_interface
import matplotlib.pyplot as plt

importlib.reload(conf)
importlib.reload(mpl_interface)
from conf import *
from mpl_interface import *

# %%
p = {"beta": 10, "J": 1, "L": 4}
c = Conf(**p)

# %%
fig, ax = plt.subplots(2, 2, figsize=(10, 10))
ax[0, 0].spinplot(c)
ax[0, 0].kinkplot(c, True)
c.assign_graph()
new_kinks = c.insert_kink()
ax[0, 1].spinplot(c)
ax[0, 1].kinkplot(c, True)
c.make_b()
c.make_btilde()
c.insert_spin(new_kinks)
c.x2_hord()
ax[1, 0].kinkplot(c, True)
c.cluster_update()
c.spin_update()
c.remove_kinks()
c.remove_spins()
ax[1, 1].spinplot(c)
ax[1, 1].kinkplot(c, True)

# %%
fig, ax = plt.subplots(2, 2, figsize=(10, 10))
ax[0, 0].spinplot(c)
ax[0, 0].kinkplot(c, True)
c.assign_graph()
new_kinks = c.insert_kink()
ax[0, 1].spinplot(c)
ax[0, 1].kinkplot(c, True)
c.make_b()
c.make_btilde()
c.insert_spin(new_kinks)
c.x2_hord()
ax[1, 0].kinkplot(c, True)
c.cluster_update()
c.spin_update()
c.remove_kinks()
c.remove_spins()
ax[1, 1].spinplot(c)
ax[1, 1].kinkplot(c, True)
