# %%
def f(n):
    l = []
    for i in range(n):
        l.append(0.1 * i)
    return l


def g(n):
    l = [0.1 * i for i in range(n)]
    return l

# %%
# %time f(10_000_000)
# Out:
# CPU times: user 261 ms, sys: 75.1 ms, total: 336 ms
# Wall time: 336 ms
# [0.0,
#  0.1,
#  0.2,
#  0.30000000000000004,
#  0.4,
#  0.5,
#  0.6000000000000001,
#  0.7000000000000001,
#  0.8,
#  0.9,
#  1.0,
#  1.1,
#  1.2000000000000002,
#  1.3,
#  1.4000000000000001,
#  1.5,
#  1.6,
#  1.7000000000000002,
#  1.8,
#  1.9000000000000001,
#  2.0,
#  2.1,
#  2.2,
#  2.3000000000000003,
#  2.4000000000000004,
#  2.5,
#  2.6,
#  2.7,
#  2.8000000000000003,
#  2.9000000000000004,
#  3.0,
#  3.1,
#  3.2,
#  3.3000000000000003,
#  3.4000000000000004,
#  3.5,
#  3.6,
#  3.7,
#  3.8000000000000003,
#  3.9000000000000004,
#  4.0,
#  4.1000000000000005,
#  4.2,
#  4.3,
#  4.4,
#  4.5,
#  4.6000000000000005,
#  4.7,
#  4.800000000000001,
#  4.9,
#  5.0,
#  5.1000000000000005,
#  5.2,
#  5.300000000000001,
#  5.4,
#  5.5,
#  5.6000000000000005,
#  5.7,
#  5.800000000000001,
#  5.9,
#  6.0,
#  6.1000000000000005,
#  6.2,
#  6.300000000000001,
#  6.4,
#  6.5,
#  6.6000000000000005,
#  6.7,
# ...

# %%
# %time g(10_000_000)
# Out:
# CPU times: user 266 ms, sys: 63.2 ms, total: 329 ms
# Wall time: 328 ms
# [0.0,
#  0.1,
#  0.2,
#  0.30000000000000004,
#  0.4,
#  0.5,
#  0.6000000000000001,
#  0.7000000000000001,
#  0.8,
#  0.9,
#  1.0,
#  1.1,
#  1.2000000000000002,
#  1.3,
#  1.4000000000000001,
#  1.5,
#  1.6,
#  1.7000000000000002,
#  1.8,
#  1.9000000000000001,
#  2.0,
#  2.1,
#  2.2,
#  2.3000000000000003,
#  2.4000000000000004,
#  2.5,
#  2.6,
#  2.7,
#  2.8000000000000003,
#  2.9000000000000004,
#  3.0,
#  3.1,
#  3.2,
#  3.3000000000000003,
#  3.4000000000000004,
#  3.5,
#  3.6,
#  3.7,
#  3.8000000000000003,
#  3.9000000000000004,
#  4.0,
#  4.1000000000000005,
#  4.2,
#  4.3,
#  4.4,
#  4.5,
#  4.6000000000000005,
#  4.7,
#  4.800000000000001,
#  4.9,
#  5.0,
#  5.1000000000000005,
#  5.2,
#  5.300000000000001,
#  5.4,
#  5.5,
#  5.6000000000000005,
#  5.7,
#  5.800000000000001,
#  5.9,
#  6.0,
#  6.1000000000000005,
#  6.2,
#  6.300000000000001,
#  6.4,
#  6.5,
#  6.6000000000000005,
#  6.7,
# ...

# %%
import numpy as np

l = np.arange(10_000_000) * 0.1
